# %% [markdown]
# # Hugging Face Datasets Demo
#
# Hugging Face Datasets is a library for easily accessing and sharing datasets. It provides a simple way to load, preprocess, and use datasets in machine learning tasks. In this demo, we will explore how to create custom datasets, specify feature formats, and save/load datasets using the Hugging Face Datasets library.
# The main features of the library include:
# - **Easy Dataset Creation**: Create datasets from dictionaries, lists, or files.
# - **Feature Specification**: Define the format of features in the dataset for optimized loading.
# - **Multiple Formats Support**: Support for various formats like NumPy, PyTorch, TensorFlow, JAX, and Pandas.
# - **Save and Load Datasets**: Save datasets to disk and load them back easily.
# - **Dataset Sharing**: Share datasets with the community or use datasets shared by others.
# - **Integration with Hugging Face Ecosystem**: Seamless integration with other Hugging Face libraries like Transformers and Tokenizers.
# - **Efficient Data Loading**: Efficiently load large datasets with lazy loading and caching.

# %% [markdown]
# # Installation

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (4.0.0)
# Requirement already satisfied: filelock in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from datasets) (2.2.0)
# Requirement already satisfied: requests>=2.32.2 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2024.2.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from datasets) (0.34.3)
# Requirement already satisfied: packaging in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.9.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (4.0.3)
# Requirement already satisfied: idna>=2.0 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from huggingface-hub>=0.24.0->datasets) (4.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from huggingface-hub>=0.24.0->datasets) (1.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from requests>=2.32.2->datasets) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from requests>=2.32.2->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/mik/Developer/MMINT/venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %% [markdown]
# # Custom Dataset Creation

# %%
import numpy as np
import torch

from datasets import Dataset

# %%
# Make a simple dataset:

texts = ["Hi there", "How are you?", "Nice to meet you"]
labels = [0, 1, 0]
vectors = np.random.randint(0, 9, (3, 5))  # Random vectors of size 5

data = {"text": texts, "label": labels, 'vector': vectors}
dataset = Dataset.from_dict(data)
print(dataset)
# Out:
# Dataset({
#     features: ['text', 'label', 'vector'],
#     num_rows: 3
# })

# %%
for item in dataset:
    print(item)
# Out:
# {'text': 'Hi there', 'label': 0, 'vector': [5, 6, 0, 5, 2]}
# {'text': 'How are you?', 'label': 1, 'vector': [5, 1, 7, 2, 0]}
# {'text': 'Nice to meet you', 'label': 0, 'vector': [5, 6, 5, 6, 5]}

# %%
# we can convert the dataset to a PyTorch Dataset:
torch_dataset = dataset.with_format("torch")
print(torch_dataset)
# Out:
# Dataset({
#     features: ['text', 'label', 'vector'],
#     num_rows: 3
# })

# %%
for item in torch_dataset:
    print(item)
# Out:
# {'text': 'Hi there', 'label': tensor(0), 'vector': tensor([0, 1, 2, 2, 3])}
# {'text': 'How are you?', 'label': tensor(1), 'vector': tensor([6, 7, 1, 3, 5])}
# {'text': 'Nice to meet you', 'label': tensor(0), 'vector': tensor([4, 2, 0, 1, 4])}

# %% [markdown]
# ## Feature Format
# We can specify the format of the features in the dataset for faster and optimized loading.

# %%
from datasets import Features, Value, Sequence, Array2D, Array3D

features = Features({
    "text": Value("string"),
    "label": Value("int64"),
    "vector": Array2D(shape=(5,1), dtype='float32'),  # 2D array with shape (5,1)
    "img": Array3D(shape=(3, 64, 64), dtype='uint8'),  # 3D array with shape (3, 64, 64)
})

data = {
    "text": ["Hi there", "How are you?", "Nice to meet you"],
    "label": [0, 1, 0],
    "vector": np.random.randint(0, 9, (3, 5, 1)).astype(np.float32),  # Random vectors of size (5,1)
    "img": np.random.randint(0, 255, (3, 3, 64, 64), dtype=np.uint8)  # Random images of shape (3, 64, 64)
}

# %%
torch_dataset = dataset.with_format("torch")
print(torch_dataset)
for item in torch_dataset:
    for key, value in item.items():
        print(f"{key}: {value.shape if isinstance(value, torch.Tensor) else value}")
# Out:
# Dataset({
#     features: ['text', 'label', 'vector', 'img'],
#     num_rows: 3
# })
# text: Hi there
# label: torch.Size([])
# vector: torch.Size([5, 1])
# img: torch.Size([3, 64, 64])
# text: How are you?
# label: torch.Size([])
# vector: torch.Size([5, 1])
# img: torch.Size([3, 64, 64])
# text: Nice to meet you
# label: torch.Size([])
# vector: torch.Size([5, 1])
# img: torch.Size([3, 64, 64])

# %% [markdown]
# # HF Datasets allows support on multiple formats like numpy, torch, tensorflow, jax, pandas, etc.

# %%
np_dataset = dataset.with_format("numpy")
print(np_dataset[0])
# Out:
# {'text': 'Hi there', 'label': 0, 'vector': array([[3.],
#        [2.],
#        [4.],
#        [7.],
#        [5.]], dtype=float32), 'img': array([[[191, 218, 114, ...,  95,  73, 128],
#         [130, 250, 213, ...,  72,  27, 109],
#         [ 48,  94,  81, ...,  89,  76, 185],
#         ...,
#         [ 24, 151, 153, ..., 150,   1, 160],
#         [ 95, 175, 137, ...,  88,  55,   4],
#         [134,  26, 185, ..., 238, 169, 162]],
#
#        [[ 74, 168,   3, ...,  92, 248, 211],
#         [ 37, 144, 248, ..., 143,  34, 241],
#         [  4, 191, 179, ...,  69, 168, 176],
#         ...,
#         [101,  65, 166, ..., 169, 228, 235],
#         [ 72,  81, 172, ...,  17,  14,  56],
#         [ 95,  72, 205, ..., 148,  60, 225]],
#
#        [[253,  42,   7, ...,   1,  91, 251],
#         [101, 109, 127, ..., 157, 193,  63],
#         [ 25, 155, 221, ..., 170,   5, 192],
#         ...,
#         [121, 192, 117, ..., 220, 158, 150],
#         [ 34,  69, 190, ..., 250,   0, 119],
#         [ 61, 203,  99, ..., 163,  75,  21]]])}

# %%
jax_dataset = dataset.with_format("jax")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 jax_dataset = dataset.with_format("jax")
#
# File ~/Developer/MMINT/venv/lib/python3.9/site-packages/datasets/arrow_dataset.py:2775, in Dataset.with_format(self, type, columns, output_all_columns, **format_kwargs)
#    2714 """Set `__getitem__` return format (type and columns). The data formatting is applied on-the-fly.
#    2715 The format `type` (for example "numpy") is used to format batches when using `__getitem__`.
#    2716
#    (...)
#    2772 ```
#    2773 """
#    2774 dataset = copy.deepcopy(self)
# -> 2775 dataset.set_format(type=type, columns=columns, output_all_columns=output_all_columns, **format_kwargs)
#    2776 return dataset
#
# File ~/Developer/MMINT/venv/lib/python3.9/site-packages/datasets/fingerprint.py:442, in fingerprint_transform.<locals>._fingerprint.<locals>.wrapper(*args, **kwargs)
#     438             validate_fingerprint(kwargs[fingerprint_name])
#     440 # Call actual function
# --> 442 out = func(dataset, *args, **kwargs)
#     444 # Update fingerprint of in-place transforms + update in-place history of transforms
#     446 if inplace:  # update after calling func so that the fingerprint doesn't change if the function fails
#
# File ~/Developer/MMINT/venv/lib/python3.9/site-packages/datasets/arrow_dataset.py:2607, in Dataset.set_format(self, type, columns, output_all_columns, **format_kwargs)
#    2605 # Check that the format_type and format_kwargs are valid and make it possible to have a Formatter
#    2606 type = get_format_type_from_alias(type)
# -> 2607 get_formatter(type, features=self._info.features, **format_kwargs)
#    2609 # Check filter column
#    2610 if isinstance(columns, str):
#
# File ~/Developer/MMINT/venv/lib/python3.9/site-packages/datasets/formatting/__init__.py:134, in get_formatter(format_type, **format_kwargs)
#     132     return _FORMAT_TYPES[format_type](**format_kwargs)
#     133 if format_type in _FORMAT_TYPES_ALIASES_UNAVAILABLE:
# --> 134     raise _FORMAT_TYPES_ALIASES_UNAVAILABLE[format_type]
#     135 else:
#     136     raise ValueError(f"Format type should be one of {list(_FORMAT_TYPES.keys())}, but got '{format_type}'")
#
#     [... skipping hidden 1 frame]
#
# Cell In[33], line 1
# ----> 1 jax_dataset = dataset.with_format("jax")
#       2 print(jax_dataset[0])
#
# File ~/Developer/MMINT/venv/lib/python3.9/site-packages/datasets/arrow_dataset.py:2775, in Dataset.with_format(self, type, columns, output_all_columns, **format_kwargs)
#    2714 """Set `__getitem__` return format (type and columns). The data formatting is applied on-the-fly.
#    2715 The format `type` (for example "numpy") is used to format batches when using `__getitem__`.
#    2716
#    (...)
#    2772 ```
#    2773 """
#    2774 dataset = copy.deepcopy(self)
# -> 2775 dataset.set_format(type=type, columns=columns, output_all_columns=output_all_columns, **format_kwargs)
#    2776 return dataset
#
# File ~/Developer/MMINT/venv/lib/python3.9/site-packages/datasets/fingerprint.py:442, in fingerprint_transform.<locals>._fingerprint.<locals>.wrapper(*args, **kwargs)
#     438             validate_fingerprint(kwargs[fingerprint_name])
#     440 # Call actual function
# --> 442 out = func(dataset, *args, **kwargs)
#     444 # Update fingerprint of in-place transforms + update in-place history of transforms
#     446 if inplace:  # update after calling func so that the fingerprint doesn't change if the function fails
#
# File ~/Developer/MMINT/venv/lib/python3.9/site-packages/datasets/arrow_dataset.py:2607, in Dataset.set_format(self, type, columns, output_all_columns, **format_kwargs)
#    2605 # Check that the format_type and format_kwargs are valid and make it possible to have a Formatter
#    2606 type = get_format_type_from_alias(type)
# -> 2607 get_formatter(type, features=self._info.features, **format_kwargs)
#    2609 # Check filter column
#    2610 if isinstance(columns, str):
#
# File ~/Developer/MMINT/venv/lib/python3.9/site-packages/datasets/formatting/__init__.py:134, in get_formatter(format_type, **format_kwargs)
#     132     return _FORMAT_TYPES[format_type](**format_kwargs)
#     133 if format_type in _FORMAT_TYPES_ALIASES_UNAVAILABLE:
# --> 134     raise _FORMAT_TYPES_ALIASES_UNAVAILABLE[format_type]
#     135 else:
#     136     raise ValueError(f"Format type should be one of {list(_FORMAT_TYPES.keys())}, but got '{format_type}'")
#
# ValueError: JAX needs to be installed to be able to return JAX arrays.

# %% [markdown]
# # Save and Load Dataset
# To save the dataset, we can use the `save_to_disk` method, and to load it back, we can use `load_from_disk`.

# %%
from datasets import load_from_disk


# Save the dataset to disk
dataset.save_to_disk("my_dataset")
# This will create a directory named "my_dataset" containing the dataset files.
# The directory structure will look like this:
# my_dataset/
# ├── dataset_info.json
# ├── dataset.arrow
# └── state.json
# where `dataset_info.json` contains metadata about the dataset,
# `dataset.arrow` contains the actual data, and `state.json` contains the state of the dataset, i.e. the
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/3 [00:00<?, ? examples/s]

# %%
# Load the dataset from disk
loaded_dataset = load_from_disk("my_dataset")

# %%
# !pwd
# Out:
# /Users/mik/Developer/MMINT/mik_tools/notebooks

# %%
dataset.to_json('dataset.json')
# Out:
# Creating json from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 170
